# %% [markdown]
# ### ARCHIVOS

# %% [markdown]
# Python emplea unos file objects para interactuar con los archivos de tu ordenador.

# %% [markdown]
# Puede manejar cualquier tipo de archivo, para algunos es posible que necesites librerías adicionales.

# %% [markdown]
# Podemos abrir archivos con **open()**, leerlos con **read() o readlines()**, cerrarlos con **close()** y escribir en ellos con **write()**.

# %% [markdown]
# Usando **open()** y w, w+, a+ nos permite sobreescribir o añadir información a la ya existente.

# %%
# Vamos a abrir el archivo test.txt.
mi_archivo=open('test.txt')

# %%
mi_archivo
# Out:
# <_io.TextIOWrapper name='test.txt' mode='r' encoding='cp1252'>

# %%
# Leemos el archivo. 
mi_archivo.read()
# Out:
# 'Esta es una linea nuevaEsta es una linea nuevaEsta es una linea nueva\nEsta linea va detras de la anterior\nY aqui ponemos otra'

# %%
# Pero, qué pasa si lo leemos más de una vez? Que nos lleva el cursor al final
mi_archivo.read()
# Out:
# ''

# %%
# Podemos reseatear el cursor así
mi_archivo.seek(0)
# Out:
# 0

# %%
mi_archivo.read()
# Out:
# 'Esta es una linea nuevaEsta es una linea nuevaEsta es una linea nueva\nEsta linea va detras de la anterior\nY aqui ponemos otra'

# %%
mi_archivo
# Out:
# <_io.TextIOWrapper name='test.txt' mode='r' encoding='cp1252'>

# %%
# Si usamos la función readlines() nos devuelve una lista para cada línea del archivo
mi_archivo.seek()
mi_archivo.readlines()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Si usamos la función readlines() nos devuelve una lista para cada línea del archivo
# ----> 2 mi_archivo.seek()
#       3 mi_archivo.readlines()
#
# TypeError: seek expected at least 1 argument, got 0

# %%
# Podemos cerrar un archivo. Siempre es buena idea cerrarlos para evitar que consuman memoria.
mi_archivo.close()

# %%
# Podemos escribir un archivo usando open y w+ que se emplea para leer y escribir sobre el archivo.
# Hay que tener en cuenta que si se usa w o w+ se elimina el contenido anterior del archivo!!!!
mi_archivo=open('test.txt','w+')

# %%
# Ahora escribimos en él
mi_archivo.write('Esta es una linea nueva')
# Out:
# 23

# %%
mi_archivo.seek(0)
mi_archivo.read()
# Out:
# 'Esta es una linea nueva'

# %%
mi_archivo.close()

# %%
# Ahora queremos añadir información nueva
mi_archivo = open('test.txt','a+')
mi_archivo.write('\nEsta linea va detras de la anterior')
mi_archivo.write('\nY aqui ponemos otra')
# Out:
# 20

# %%
mi_archivo.seek(0)
mi_archivo.read()
# Out:
# 'Esta es una linea nueva\nEsta linea va detras de la anterior\nY aqui ponemos otra'

# %%
mi_archivo.seek(0)
print(mi_archivo.read())
# Out:
# Esta es una linea nueva
# Esta linea va detras de la anterior
# Y aqui ponemos otra

# %%
# También podemos iterar sobre los archivos
mi_archivo.seek(0)
for line in mi_archivo:
    print(line)
# Out:
# Esta es una linea nueva
#
# Esta linea va detras de la anterior
#
# Y aqui ponemos otra

# %%
mi_archivo.close()

# %%
mi_archivo=open("Prueba clase.txt", "a+")
mi_archivo
# Out:
# <_io.TextIOWrapper name='Prueba clase.txt' mode='a+' encoding='cp1252'>

# %%
mi_archivo.read()
# Out:
# ''

# %%
mi_archivo.write("Esta es una prueba hecha en clase\nHe añadido 2 líneas\nEsta es la última línea")
# Out:
# 77

# %%
mi_archivo.read()
# Out:
# ''

# %%
mi_archivo.seek(0)
print(mi_archivo.read())
# Out:
# Esta es una prueba hecha en clase/nHe añadido 2 líneas/nEsta es la última líneaEsta es una prueba hecha en clase/nHe añadido 2 líneas/nEsta es la última líneaEsta es una prueba hecha en clase
# He añadido 2 líneas
# Esta es la última líneaEsta es una prueba hecha en clase
# He añadido 2 líneas
# Esta es la última línea

# %%
mi_archivo=open("Prueba clase.txt", "w+")

# %%
mi_archivo.close()

# %%
mi_archivo=open("Prueba clase.txt")
mi_archivo
# Out:
# <_io.TextIOWrapper name='Prueba clase.txt' mode='r' encoding='cp1252'>

# %%
mi_archivo.read()
# Out:
# 'Esta es una prueba hecha en clase/nHe añadido 2 líneas/nEsta es la última línea'

# %%
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 mi_archivo.write("Esta es una prueba hecha en clase\nHe añadido 2 líneas\nEsta es la última línea")
#
# UnsupportedOperation: not writable

# %%
mi_archivo=open("Prueba clase.txt")
mi_archivo
# Out:
# <_io.TextIOWrapper name='Prueba clase.txt' mode='r' encoding='cp1252'>

# %%
mi_archivo.read()
# Out:
# 'Esta es una prueba hecha en clase/nHe añadido 2 líneas/nEsta es la última línea'

# %%
mi_archivo=open("Prueba clase.txt","w+")
mi_archivo
# Out:
# <_io.TextIOWrapper name='Prueba clase.txt' mode='w+' encoding='cp1252'>

# %%
mi_archivo.seek(0)
mi_archivo.read()
# Out:
# ''

# %%
mi_archivo.write("Esta es la primera línea\nEsta es la segunda línea\nEsta es la última línea")
# Out:
# 73

# %%
mi_archivo.seek(0)
mi_archivo.readline()
# Out:
# 'Esta es la primera línea\n'

# %%
mi_archivo.close()

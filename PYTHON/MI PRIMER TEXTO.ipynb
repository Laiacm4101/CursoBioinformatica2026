# %% [markdown]
# # MI PRIMER TEXTO

# %% [markdown]
# ## Este es mi primer notebook y voy a hacer lo siguiente.

# %% [markdown]
# Una lista **enumerada:**
# 1. Primero
# 2. Segundo
# 3. Tercero

# %% [markdown]
# Una lista **por puntos:**
# - Primero
# - Segundo
# - Tercero

# %% [markdown]
# Mi primer código:

# %%
mi_primera_frase = "Hello World"

# %%
#Debo usar la función print() para que salga algo al ejecutar.
mi_primera_frase = "Hello World"
print(mi_primera_frase)
# Out:
# Hello World

# %%
numeros=(10,20,30,40,50)
media=sum(numeros)/len(numeros)
print(media)
# Out:
# 30.0

# %% [markdown]
# ## Finalizamos con una bonita imagen

# %% [markdown]
# ![imagen-llama.jpg](attachment:7ff69af4-7c4f-45c3-b44d-1e1c9cff157a.jpg)
